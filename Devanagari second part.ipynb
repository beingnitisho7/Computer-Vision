# %%
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import ImageFile
# %matplotlib inline
# Out:
# D:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import cv2
image=cv2.imread('DevnGri\Ka.jpg',0)
plt.imshow(image,cmap="gray")

# %%
plt.imshow(image[40:200, 100:300]) #crop image

# %%
size=image.shape

edit_image=image.copy()
thresh=0 ##backgroup pixel ko value

bg_pixels=np.repeat(thresh,size[1]) #siz[1]le no of column dinxa size[0] le num of row dinxa
for row in range(1,size[0]): #1st row dekhi last samma jane, row ma garne
    if np.equal(bg_pixels, image[row]).any()==True: #image[row] le euta euta liraxa equal xa vane backgroud ho vanne bujhxa. 
        #tara mathi 0 lya xa tei vayera ulto kama vairaxa.
    
        top=row
        break
plt.imshow(edit_image[top:])
